# %% [markdown]
# # SQL Project
# You were hired by Ironhack to perform an Analytics Consulting Project entitled: competitive landscape.
#
# Your mission is to create and populate an appropriate database with many coding schools that are our competition, as well as design an suitable queries that answer business questions of interest (to be defined by you)

# %% [markdown]
# **Suggested Steps in the Project:**
#
#
# *   Read this notebook and understand each function. Comment the code appropriately
#
# *   Populate the list of schools with a wider variety of schools (how are you going to get the school ID?)
#
# * Take a look at the obtained dataframes. What dimensions do you have? what keys do you have? how could the different dataframes be connected?
#
# * Go back to the drawing board and try to create an entity relationship diagram for tables available
#
# * Once you have the schemas you want, you will need to:
#   - create the suitable SQL queries to create the tables and populate them
#   - run these queries using the appropriate Python connectors
#
# * Bonus: How will this datamodel be updated in the future? Please write auxiliary functions that test the database for data quality issues. For example: how could you make sure you only include the most recent comments when you re-run the script?
#
#
# # Suggested Deliverables
#
# * 7 minute presentation of data model created, decision process and business analysis proposed
#
# * exported .sql file with the final schema
#
# * Supporting python files used to generate all logic
#
# * High level documentation explaining tables designed and focusing on update methods
#
# Crucial hint: check out the following tutorial:
# https://www.dataquest.io/blog/sql-insert-tutorial/

# %%
schools_main = {
#top 10 coding
'actualize': '10505',
'clarusway': '11539',   
'learningfuze': '10862',
'springboard': '11035',  
'codesmith': '10643',
'code-platoon': '10627',
'knowledgehut': '10846',   
'udacity': '11118', 
'altcademy': '10517',
'tech-elevator': '11056',
    
#top 10 Data
#2'springboard': '11035', 
'dataquest': '10683',
'syntax-technologies': '11797',
'ironhack': '10828',
'tripleten': '11225', 
'colaberry': '11718',
'maven-analytics': '11740',
#2'udacity': '11118', 
'brainstation': '10571',
'ccs-learning-academy': '11736',

#top 10 ux
'designlab': '10697',    
#3'springboard': '11035',   
#2'ironhack': '10828',
'ux-design-institute': '11150',
'mento-design-academy': '11584',
'beginex': '10546',
#3'udacity': '11118', 
#2'brainstation': '10571',
'design-sprint-school': '10698',
'general-assembly': '10761'}

import re
import pandas as pd
from pandas.io.json import json_normalize
import requests



def get_comments_school(school):
    TAG_RE = re.compile(r'<[^>]+>')
    # defines url to make api call to data -> dynamic with school if you want to scrape competition
    url = "https://www.switchup.org/chimera/v1/school-review-list?mainTemplate=school-review-list&path=%2Fbootcamps%2F" + school + "&isDataTarget=false&page=3&perPage=10000&simpleHtml=true&truncationLength=250"
    #makes get request and converts answer to json
    # url defines the page of all the information, request is made, and information is returned to data variable
    data = requests.get(url).json()
    #converts json to dataframe
    reviews =  pd.DataFrame(data['content']['reviews'])

    #aux function to apply regex and remove tags
    def remove_tags(x):
        return TAG_RE.sub('',x)
    reviews['review_body'] = reviews['body'].apply(remove_tags)
    reviews['school'] = school
    return reviews

# %%
TAG_RE = re.compile(r'<[^>]+>')
def remove_tags(x):
    return TAG_RE.sub('',x)

# %%
comments = [get_comments_school(i) for i in schools_main.keys()]

comments = pd.concat(comments)

# %%
to_drop = ["body", "name", "hostProgramName", "rawBody","queryDate", "user", "comments" ]
for i in to_drop:
    comments.drop(i, axis=1, inplace=True)
comments
# Out:
#          id  anonymous  graduatingYear isAlumni  \
# 0    305645       True          2023.0    False
# 1    305528      False          2023.0    False
# 2    304869       True          2023.0     True
# 3    304868      False          2023.0    False
# 4    304866       True          2023.0     True
# ..      ...        ...             ...      ...
# 994  231691      False          2013.0     True
# 995  231827      False             NaN    False
# 996  231816      False             NaN    False
# 997  231836      False             NaN    False
# 998  231574      False             NaN     None
#
#                                    jobTitle  \
# 0
# 1
# 2
# 3                      Senior IT Specialist
# 4
# ..                                      ...
# 994  Software Developer at Cengage Learning
# 995
# 996
# 997
# 998                                    None
#
#                                                tagline   createdAt  \
# 0                     Was great! They really teach you  10/13/2023
# 1                    Full Stack Web Development Course  10/10/2023
# 2    A great coding boot camp experience! Highly re...   9/14/2023
# 3              Exceptional Coding Boot Camp Experience   9/14/2023
# 4                                  Phenomenal Bootcamp   9/14/2023
# ..                                                 ...         ...
# 994  From 2nd grade teacher to full-stack web devel...   6/29/2014
# 995  What you get out of the program really depends...   6/15/2014
# 996  The bitmaker program provides opportunities an...   6/15/2014
# 997  Bitmaker is the best way to motivate and accel...   6/15/2014
# 998                                               NULL  12/19/2013
#
#                                     program overallScore overall curriculum  \
# 0    Actualize Coding Bootcamp: Online Live          5.0     5.0        5.0
# 1    Actualize Coding Bootcamp: Online Live          5.0     5.0        5.0
# 2    Actualize Coding Bootcamp: Online Live          5.0     5.0        5.0
# 3      Actualize Coding Bootcamp: Full-Time          5.0     5.0        5.0
# 4    Actualize Coding Bootcamp: Online Live          5.0     5.0        5.0
# ..                                      ...          ...     ...        ...
# 994          Software Engineering Immersive          5.0     5.0        5.0
# 995                                                  3.0     3.0        NaN
# 996                                                  5.0     5.0        NaN
# 997                                                  5.0     5.0        NaN
# 998                                    None          4.0     4.0        NaN
#
#     jobSupport                                        review_body  \
# 0          5.0  Great program. They really teach how to code n...
# 1          5.0  Actualize's slogan is "Educators first, develo...
# 2          5.0  There are so many great perks to this boot cam...
# 3          5.0  I recently completed an inconceivable adventur...
# 4          5.0  Actualize is a well-thought-out curriculum wit...
# ..         ...                                                ...
# 994        5.0  My experience at General Assembly's Web Develo...
# 995        NaN  What you get out of the program really depends...
# 996        NaN  Personally I had a great experience at Bitmake...
# 997        NaN  I was in the 3rd cohort and have had a success...
# 998        NaN  I'm surprised by the reviews below. My experie...
#
#                school
# 0           actualize
# 1           actualize
# 2           actualize
# 3           actualize
# 4           actualize
# ..                ...
# 994  general-assembly
# 995  general-assembly
# 996  general-assembly
# 997  general-assembly
# 998  general-assembly
#
# [9432 rows x 14 columns]

# %%
from pandas.io.json import json_normalize

def get_school_info(school, school_id):
    url = 'https://www.switchup.org/chimera/v1/bootcamp-data?mainTemplate=bootcamp-data%2Fdescription&path=%2Fbootcamps%2F'+ str(school) + '&isDataTarget=false&bootcampId='+ str(school_id) + '&logoTag=logo&truncationLength=250&readMoreOmission=...&readMoreText=Read%20More&readLessText=Read%20Less'

    data = requests.get(url).json()

    data.keys()

    courses = data['content']['courses']
    courses_df = pd.DataFrame(courses, columns= ['courses'])

    locations = data['content']['locations']
    locations_df = json_normalize(locations)

    badges_df = pd.DataFrame(data['content']['meritBadges'])

    website = data['content']['webaddr']
    description = data['content']['description']
    logoUrl = data['content']['logoUrl']
    school_df = pd.DataFrame([website,description,logoUrl]).T
    school_df.columns =  ['website','description','LogoUrl']

    locations_df['school'] = school
    courses_df['school'] = school
    badges_df['school'] = school
    school_df['school'] = school


    locations_df['school_id'] = school_id
    courses_df['school_id'] = school_id
    badges_df['school_id'] = school_id
    school_df['school_id'] = school_id

    return locations_df, courses_df, badges_df, school_df

locations_list = []
courses_list = []
badges_list = []
schools_list = []

for school, id in schools_main.items():
    a,b,c,d = get_school_info(school,id)

    locations_list.append(a)
    courses_list.append(b)
    badges_list.append(c)
    schools_list.append(d)
# Out:
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_8836\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_8836\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_8836\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_8836\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_8836\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_8836\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_8836\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_8836\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_8836\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_8836\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_8836\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_8836\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_8836\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_8836\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_8836\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_8836\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_8836\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_8836\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_8836\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_8836\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_8836\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_8836\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_8836\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_8836\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)

# %%
locations = pd.concat(locations_list)
locations
# Out:
#       id                       description  country.id    country.name  \
# 0  15703        Chicago, IL, United States         1.0   United States
# 1  16019                            Online         NaN             NaN
# 0  17789                            Online         NaN             NaN
# 0  16712         Irvine, CA, United States         1.0   United States
# 1  16806      San Diego, CA, United States         1.0   United States
# 2  16970                            Online         NaN             NaN
# 0  16013                            Online         NaN             NaN
# 0  16002    Los Angeles, CA, United States         1.0   United States
# 1  16328  New York City, NY, United States         1.0   United States
# 2  16595                            Online         NaN             NaN
# 3  17438                Temporarily Online         1.0   United States
# 0  15909        Chicago, IL, United States         1.0   United States
# 1  16764                            Online         NaN             NaN
# 0  15775                            Online         NaN             NaN
# 0  15807                            Online         NaN             NaN
# 0  16297                            Online         NaN             NaN
# 0  16035      Cleveland, OH, United States         1.0   United States
# 1  16127       Columbus, OH, United States         1.0   United States
# 2  16143     Cincinnati, OH, United States         1.0   United States
# 3  16477     Pittsburgh, PA, United States         1.0   United States
# 4  17272                            Online         NaN             NaN
# 5  17722         Dallas, TX, United States         1.0   United States
# 0  16378                            Online         NaN             NaN
# 0  18261                            Online         NaN             NaN
# 0  15901                   Berlin, Germany        57.0         Germany
# 1  16022               Mexico City, Mexico        29.0          Mexico
# 2  16086            Amsterdam, Netherlands        59.0     Netherlands
# 3  16088                 Sao Paulo, Brazil        42.0          Brazil
# 4  16109                     Paris, France        38.0          France
# 5  16375          Miami, FL, United States         1.0   United States
# 6  16376                     Madrid, Spain        12.0           Spain
# 7  16377                  Barcelona, Spain        12.0           Spain
# 8  16709                  Lisbon, Portugal        28.0        Portugal
# 9  17233                            Online         NaN             NaN
# 0  17154                            Online         NaN             NaN
# 0  18073                            Online         NaN             NaN
# 0  18116                            Online         NaN             NaN
# 0  15935                 New York City, NY         1.0   United States
# 1  15985                   Toronto, Canada         2.0          Canada
# 2  16010                 Vancouver, Canada         2.0          Canada
# 3  16909                        Boston, MA         1.0   United States
# 4  16910                       Chicago, IL         1.0   United States
# 5  16940                            Online         NaN             NaN
# 6  17706                         Miami, FL         1.0   United States
# 7  17731                        London, UK        11.0  United Kingdom
# 0  18109                            Online         NaN             NaN
# 0  15816                            Online         NaN             NaN
# 0  16808                            Online         NaN             NaN
# 0  17923                            Online         NaN             NaN
# 0  15948  New York City, NY, United States         1.0   United States
# 1  17447                            Online         NaN             NaN
# 0  16308                            Online         NaN             NaN
# 0  16360                 New York City, NY         1.0   United States
# 1  16372                            Online         NaN             NaN
# 2  16961                        London, UK        11.0  United Kingdom
# 3  17033                   Toronto, Canada         2.0          Canada
#
#   country.abbrev  state.id        state.name state.abbrev  state.keyword  \
# 0             US      15.0          Illinois           IL       illinois
# 1            NaN       1.0            Online       Online         online
# 0            NaN       1.0            Online       Online         online
# 0             US       6.0        California           CA     california
# 1             US       6.0        California           CA     california
# 2            NaN       1.0            Online       Online         online
# 0            NaN       1.0            Online       Online         online
# 0             US       6.0        California           CA     california
# 1             US      34.0          New York           NY       new-york
# 2            NaN       1.0            Online       Online         online
# 3             US       NaN               NaN          NaN            NaN
# 0             US      15.0          Illinois           IL       illinois
# 1            NaN       1.0            Online       Online         online
# 0            NaN       1.0            Online       Online         online
# 0            NaN       1.0            Online       Online         online
# 0            NaN       1.0            Online       Online         online
# 0             US      37.0              Ohio           OH           ohio
# 1             US      37.0              Ohio           OH           ohio
# 2             US      37.0              Ohio           OH           ohio
# 3             US      40.0      Pennsylvania           PA   pennsylvania
# 4            NaN       1.0            Online       Online         online
# 5             US      45.0             Texas           TX          texas
# 0            NaN       1.0            Online       Online         online
# 0            NaN       1.0            Online       Online         online
# 0             DE       NaN               NaN          NaN            NaN
# 1             MX       NaN               NaN          NaN            NaN
# 2             NL       NaN               NaN          NaN            NaN
# 3             BR       NaN               NaN          NaN            NaN
# 4             FR       NaN               NaN          NaN            NaN
# 5             US      11.0           Florida           FL        florida
# 6             ES       NaN               NaN          NaN            NaN
# 7             ES       NaN               NaN          NaN            NaN
# 8             PT       NaN               NaN          NaN            NaN
# 9            NaN       1.0            Online       Online         online
# 0            NaN       1.0            Online       Online         online
# 0            NaN       1.0            Online       Online         online
# 0            NaN       1.0            Online       Online         online
# 0             US      34.0          New York           NY       new-york
# 1             CA      66.0           Ontario           ON
# 2             CA      71.0  British Columbia           BC
# 3             US      23.0     Massachusetts           MA  massachusetts
# 4             US      15.0          Illinois           IL       illinois
# 5            NaN       1.0            Online       Online         online
# 6             US      11.0           Florida           FL        florida
# 7             GB       NaN               NaN          NaN            NaN
# 0            NaN       1.0            Online       Online         online
# 0            NaN       1.0            Online       Online         online
# 0            NaN       1.0            Online       Online         online
# 0            NaN       1.0            Online       Online         online
# 0             US      34.0          New York           NY       new-york
# 1            NaN       1.0            Online       Online         online
# 0            NaN       1.0            Online       Online         online
# 0             US      34.0          New York           NY       new-york
# 1            NaN       1.0            Online       Online         online
# 2             GB       NaN               NaN          NaN            NaN
# 3             CA      66.0           Ontario           ON
#
#    city.id           city.name   city.keyword                school school_id
# 0     39.0             Chicago        chicago             actualize     10505
# 1      NaN                 NaN            NaN             actualize     10505
# 0      NaN                 NaN            NaN             clarusway     11539
# 0     24.0              Irvine         irvine          learningfuze     10862
# 1     11.0           San Diego      san-diego          learningfuze     10862
# 2      NaN                 NaN            NaN          learningfuze     10862
# 0      NaN                 NaN            NaN           springboard     11035
# 0     10.0         Los Angeles    los-angeles             codesmith     10643
# 1   1507.0                 NYC  new-york-city             codesmith     10643
# 2      NaN                 NaN            NaN             codesmith     10643
# 3  31234.0  Temporarily Online    temp-online             codesmith     10643
# 0     39.0             Chicago        chicago          code-platoon     10627
# 1      NaN                 NaN            NaN          code-platoon     10627
# 0      NaN                 NaN            NaN          knowledgehut     10846
# 0      NaN                 NaN            NaN               udacity     11118
# 0      NaN                 NaN            NaN             altcademy     10517
# 0     71.0           Cleveland      cleveland         tech-elevator     11056
# 1     70.0            Columbus       columbus         tech-elevator     11056
# 2     72.0          Cincinnati     cincinnati         tech-elevator     11056
# 3     78.0          Pittsburgh     pittsburgh         tech-elevator     11056
# 4      NaN                 NaN            NaN         tech-elevator     11056
# 5     83.0              Dallas         dallas         tech-elevator     11056
# 0      NaN                 NaN            NaN             dataquest     10683
# 0      NaN                 NaN            NaN   syntax-technologies     11797
# 0  31156.0              Berlin         berlin              ironhack     10828
# 1  31175.0         Mexico City    mexico-city              ironhack     10828
# 2  31168.0           Amsterdam      amsterdam              ironhack     10828
# 3  31121.0           Sao Paulo      sao-paulo              ironhack     10828
# 4  31136.0               Paris          paris              ironhack     10828
# 5     31.0               Miami          miami              ironhack     10828
# 6  31052.0              Madrid         madrid              ironhack     10828
# 7  31170.0           Barcelona      barcelona              ironhack     10828
# 8  31075.0              Lisbon         lisbon              ironhack     10828
# 9      NaN                 NaN            NaN              ironhack     10828
# 0      NaN                 NaN            NaN             tripleten     11225
# 0      NaN                 NaN            NaN             colaberry     11718
# 0      NaN                 NaN            NaN       maven-analytics     11740
# 0   1507.0                 NYC  new-york-city          brainstation     10571
# 1  31152.0             Toronto        toronto          brainstation     10571
# 2  31138.0           Vancouver      vancouver          brainstation     10571
# 3     47.0              Boston         boston          brainstation     10571
# 4     39.0             Chicago        chicago          brainstation     10571
# 5      NaN                 NaN            NaN          brainstation     10571
# 6     31.0               Miami          miami          brainstation     10571
# 7  31176.0              London         london          brainstation     10571
# 0      NaN                 NaN            NaN  ccs-learning-academy     11736
# 0      NaN                 NaN            NaN             designlab     10697
# 0      NaN                 NaN            NaN   ux-design-institute     11150
# 0      NaN                 NaN            NaN  mento-design-academy     11584
# 0   1507.0                 NYC  new-york-city               beginex     10546
# 1      NaN                 NaN            NaN               beginex     10546
# 0      NaN                 NaN            NaN  design-sprint-school     10698
# 0   1507.0                 NYC  new-york-city      general-assembly     10761
# 1      NaN                 NaN            NaN      general-assembly     10761
# 2  31176.0              London         london      general-assembly     10761
# 3  31152.0             Toronto        toronto      general-assembly     10761

# %%
courses = pd.concat(courses_list)
display(courses)
# Out:
#                                               courses            school  \
# 0                Actualize Coding Bootcamp: Full-Time         actualize
# 1                Actualize Coding Bootcamp: Part-Time         actualize
# 2              Actualize Coding Bootcamp: Online Live         actualize
# 0                             AWS Solutions Architect         clarusway
# 1   AWS Solutions Architect - Premium Full Time/Pa...         clarusway
# ..                                                ...               ...
# 9                    React Development (Short Course)  general-assembly
# 10          Software Engineering Bootcamp (Full-Time)  general-assembly
# 11              User Experience Design (Short Course)  general-assembly
# 12        User Experience Design Bootcamp (Full-Time)  general-assembly
# 13                       Visual Design (Short Course)  general-assembly
#
#    school_id
# 0      10505
# 1      10505
# 2      10505
# 0      11539
# 1      11539
# ..       ...
# 9      10761
# 10     10761
# 11     10761
# 12     10761
# 13     10761
#
# [180 rows x 3 columns]

# %%
badges = pd.concat(badges_list)
badges["description"] = badges["description"].apply(remove_tags)
badges
# Out:
#                  name            keyword  \
# 0    Available Online   available_online
# 1    Flexible Classes   flexible_classes
# 0    Available Online   available_online
# 1    Flexible Classes   flexible_classes
# 0    Available Online   available_online
# ..                ...                ...
# 1    Flexible Classes   flexible_classes
# 0    Available Online   available_online
# 1   Verified Outcomes  verified_outcomes
# 2    Flexible Classes   flexible_classes
# 3     Accepts GI Bill    accepts_gi_bill
#
#                                           description                school  \
# 0                  School offers fully online courses             actualize
# 1         School offers part-time and evening classes             actualize
# 0                  School offers fully online courses             clarusway
# 1         School offers part-time and evening classes             clarusway
# 0                  School offers fully online courses          learningfuze
# ..                                                ...                   ...
# 1         School offers part-time and evening classes  design-sprint-school
# 0                  School offers fully online courses      general-assembly
# 1   School publishes a third-party verified outcom...      general-assembly
# 2         School offers part-time and evening classes      general-assembly
# 3                          School accepts the GI Bill      general-assembly
#
#    school_id
# 0      10505
# 1      10505
# 0      11539
# 1      11539
# 0      10862
# ..       ...
# 1      10698
# 0      10761
# 1      10761
# 2      10761
# 3      10761
#
# [64 rows x 5 columns]

# %%
schools = pd.concat(schools_list)

def schools_cleaning(row):
    from bs4 import BeautifulSoup
    soup = BeautifulSoup(row)
    text = [tag.get_text() for tag in soup.find_all(['p', 'span'])]
    return ' '.join(text)

schools["description"] = schools["description"].apply(schools_cleaning)

# %%
schools = schools.set_index("school").reset_index().set_index("school_id").reset_index()
schools
# Out:
#    school_id                school  \
# 0      10505             actualize
# 1      11539             clarusway
# 2      10862          learningfuze
# 3      11035           springboard
# 4      10643             codesmith
# 5      10627          code-platoon
# 6      10846          knowledgehut
# 7      11118               udacity
# 8      10517             altcademy
# 9      11056         tech-elevator
# 10     10683             dataquest
# 11     11797   syntax-technologies
# 12     10828              ironhack
# 13     11225             tripleten
# 14     11718             colaberry
# 15     11740       maven-analytics
# 16     10571          brainstation
# 17     11736  ccs-learning-academy
# 18     10697             designlab
# 19     11150   ux-design-institute
# 20     11584  mento-design-academy
# 21     10546               beginex
# 22     10698  design-sprint-school
# 23     10761      general-assembly
#
#                                               website  \
# 0   anyonecanlearntocode.com/?utm_source=switchup&...
# 1                                      clarusway.com/
# 2                                    learningfuze.com
# 3   www.springboard.com/?utm_source=switchup&utm_m...
# 4                                    www.codesmith.io
# 5                                 www.codeplatoon.org
# 6                                www.knowledgehut.com
# 7   www.udacity.com/?utm_source=switchup&utm_mediu...
# 8                                   www.altcademy.com
# 9                                www.techelevator.com
# 10                                   www.dataquest.io
# 11                               www.syntaxtechs.com/
# 12                                www.ironhack.com/en
# 13  tripleten.com/?utm_source=referral&utm_medium=...
# 14                                 www.colaberry.com/
# 15                             www.mavenanalytics.io/
# 16                                    brainstation.io
# 17                            ccslearningacademy.com/
# 18                                      designlab.com
# 19                             uxdesigninstitute.com/
# 20                         //www.mentodesign.academy/
# 21                                    www.beginex.com
# 22                         www.designsprintschool.com
# 23  generalassemb.ly?utm_source=switchup&utm_mediu...
#
#                                           description  \
# 0   Actualize is a coding bootcamp that values qua...
# 1   Clarusway is a highly respected IT training sc...
# 2   LearningFuze is an immersive, 14-week web deve...
# 3   Springboard is an online learning platform tha...
# 4   Codesmith’s Software Engineering Immersive pro...
# 5   Code Platoon is a 501(c)3 non-profit that help...
# 6   KnowledgeHut is a leading training provider, h...
# 7   Udacity is the trusted market leader in talent...
# 8   Altcademy is a 100% online education institute...
# 9   Tech Elevator offers a full-stack coding bootc...
# 10  Master data skills. Build your career.Dataques...
# 11  Syntax Technologies is the world’s leading onl...
# 12  Ironhack is a global tech school with 9 campus...
# 13  Tripleten changed their brand name from Practi...
# 14  Colaberry offers instructor-led remote and sel...
# 15  Maven Analytics is an online, guided learning ...
# 16  BrainStation is the global leader in digital s...
# 17  TECH TRAINING BY TECH PROFESSIONALSCCS Learnin...
# 18  Designlab teaches in-demand UX/UI design skill...
# 19  The UX Design Institute offers 6 month, online...
# 20  Mento Design Academy is a UX & UI Bootcamp des...
# 21  Beginex is a selective part-time UX career acc...
# 22  The best program to learn and practice online ...
# 23  General Assembly is a global community of almo...
#
#                                               LogoUrl
# 0   https://d92mrp7hetgfk.cloudfront.net/images/si...
# 1   https://d92mrp7hetgfk.cloudfront.net/images/si...
# 2   https://d92mrp7hetgfk.cloudfront.net/images/si...
# 3   https://d92mrp7hetgfk.cloudfront.net/images/si...
# 4   https://d92mrp7hetgfk.cloudfront.net/images/si...
# 5   https://d92mrp7hetgfk.cloudfront.net/images/si...
# 6   https://d92mrp7hetgfk.cloudfront.net/images/si...
# 7   https://d92mrp7hetgfk.cloudfront.net/images/si...
# 8   https://d92mrp7hetgfk.cloudfront.net/images/si...
# 9   https://d92mrp7hetgfk.cloudfront.net/images/si...
# 10  https://d92mrp7hetgfk.cloudfront.net/images/si...
# 11  https://d92mrp7hetgfk.cloudfront.net/images/si...
# 12  https://d92mrp7hetgfk.cloudfront.net/images/si...
# 13  https://d92mrp7hetgfk.cloudfront.net/images/si...
# 14  https://d92mrp7hetgfk.cloudfront.net/images/si...
# 15  https://d92mrp7hetgfk.cloudfront.net/images/si...
# 16  https://d92mrp7hetgfk.cloudfront.net/images/si...
# 17  https://d92mrp7hetgfk.cloudfront.net/images/si...
# 18  https://d92mrp7hetgfk.cloudfront.net/images/si...
# 19  https://d92mrp7hetgfk.cloudfront.net/images/si...
# 20  https://d92mrp7hetgfk.cloudfront.net/images/si...
# 21  https://d92mrp7hetgfk.cloudfront.net/images/si...
# 22  https://d92mrp7hetgfk.cloudfront.net/images/si...
# 23  https://d92mrp7hetgfk.cloudfront.net/images/si...

# %%
query=("""CREATE TABLE IF NOT EXISTS bootcamp.schools
            (school_id INT NOT NULL PRIMARY KEY,
            school_name VARCHAR(50) NOT NULL,
            website VARCHAR(250)
            )""")
cursor.execute(query)

query=("""CREATE TABLE IF NOT EXISTS bootcamp.programs
            (program_id INT NOT NULL PRIMARY KEY,
            program_name VARCHAR(50) NOT NULL,
            school_id INT NOT NULL,
            FOREIGN KEY (school_id) REFERENCES school(school_id)
            )""")
cursor.execute(query)

query=("""CREATE TABLE IF NOT EXISTS bootcamp.comments
            (comment_id INT NOT NULL PRIMARY KEY,
            anonymous boolean NOT NULL,
            year TINYINT,
            job_title VARCHAR(250),
            alumni NOT NULL boolean,
            comment_date date NOT NULL,
            program_id INT NOT NULL,
            overall_score float NOT NULL,
            curric_score float NOT NULL,
            job_score float NOT NULL,
            school_id INT NOT NULL,
            FOREIGN KEY (program_id) REFERENCES programs(program_id),
            FOREIGN KEY (school_id) REFERENCES schools(school_id)
            )""")
cursor.execute(query)

query = (""" CREATE TABLE IF NOT EXISTS bootcamp.location
            (location_id INT NOT NULL PRIMARY KEY, 
            country_id INT NOT NULL, 
            country_name VARCHAR(35) NOT NULL,
            city_id INT NOT NULL, 
            city_name VARCHAR(35) NOT NULL, 
            school_id INT NOT NULL,
            FOREIGN KEY (school_id) REFERENCES schools(school_id)
            )""")
cursor.execute(query)
