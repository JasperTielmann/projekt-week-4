# %% [markdown]
# # SQL Project
# You were hired by Ironhack to perform an Analytics Consulting Project entitled: competitive landscape.
#
# Your mission is to create and populate an appropriate database with many coding schools that are our competition, as well as design an suitable queries that answer business questions of interest (to be defined by you)

# %% [markdown]
# **Suggested Steps in the Project:**
#
#
# *   Read this notebook and understand each function. Comment the code appropriately
#
# *   Populate the list of schools with a wider variety of schools (how are you going to get the school ID?)
#
# * Take a look at the obtained dataframes. What dimensions do you have? what keys do you have? how could the different dataframes be connected?
#
# * Go back to the drawing board and try to create an entity relationship diagram for tables available
#
# * Once you have the schemas you want, you will need to:
#   - create the suitable SQL queries to create the tables and populate them
#   - run these queries using the appropriate Python connectors
#
# * Bonus: How will this datamodel be updated in the future? Please write auxiliary functions that test the database for data quality issues. For example: how could you make sure you only include the most recent comments when you re-run the script?
#
#
# # Suggested Deliverables
#
# * 7 minute presentation of data model created, decision process and business analysis proposed
#
# * exported .sql file with the final schema
#
# * Supporting python files used to generate all logic
#
# * High level documentation explaining tables designed and focusing on update methods
#
# Crucial hint: check out the following tutorial:
# https://www.dataquest.io/blog/sql-insert-tutorial/

# %%
schools_main = {'le-wagon': '10868',
 'springboard': '11035',
 'udacity': '11118',
 'shecodes': '11014',
 'ironhack': '10828',
 'app-academy': '10525',
 'designlab': '10697',
 'nucamp': '10923',
 'thinkful': '11098',
 'software-development-academy': '11030',
 'coding-dojo': '10659',
 'makers-academy': '10874',
 'product-gym': '10959',
 'actualize': '10505',
 'edureka': '11739',
 'careerist': '11280',
 'simplilearn': '11016',
 'nyc-data-science-academy': '10925',
 'the-tech-academy': '11091',
 'la-capsule': '10853',
 'acte': '11735',
 'brainstation': '10571',
 'hack-reactor': '10788',
 'codesmith': '10643',
 'dataquest': '10683',
 'jedha': '10837',
 'greyatom-school-of-data-science': '10776',
 'academia-de-codigo': '10494',
 'microverse': '10888',
 'juno-college-of-technology': '10787',
 'datascientest': '11232',
 'clarusway': '11539',
 'product-school': '10960',
 'knowledgehut': '10846',
 'hyperiondev': '10801',
 'tech-elevator': '11056',
 'evolve-security-academy': '10743',
 'school-of-it': '11006',
 'code-institute': '10619',
 'vertical-institute': '11241',
 'isdi-coders': '11024',
 'tripleten': '11225',
 'altcademy': '10517',
 'happyer-skills': '11518',
 'bloomtech': '10854',
 'devcodecamp': '10703',
 'xccelerate': '11175',
 'developers-institute': '10705',
 'neoland': '10906',
 'careerfoundry': '10581',
 '4geeks-academy': '10492',
 'learningfuze': '10862',
 'galvanize': '10754',
 'coding-temple': '10664',
 'hacktiv8': '10791',
 'codeworks': '10650',
 'wbs-coding-school': '11243',
 'ubiqum-code-academy': '11111',
 'digitalcrafts': '10719',
 'ux-design-institute': '11150',
 'code-fellows': '10614',
 'yellow-tail-tech': '11545',
 'fullstack-academy': '10751',
 'claim-academy': '10589',
 'rocket-academy': '11483',
 'skillcrush': '11020',
 'rmotr': '10987'}

import re
import pandas as pd
from pandas.io.json import json_normalize
import requests



def get_comments_school(school):
    TAG_RE = re.compile(r'<[^>]+>')
    # defines url to make api call to data -> dynamic with school if you want to scrape competition
    url = "https://www.switchup.org/chimera/v1/school-review-list?mainTemplate=school-review-list&path=%2Fbootcamps%2F" + school + "&isDataTarget=false&page=3&perPage=10000&simpleHtml=true&truncationLength=250"
    #makes get request and converts answer to json
    # url defines the page of all the information, request is made, and information is returned to data variable
    data = requests.get(url).json()
    #converts json to dataframe
    reviews =  pd.DataFrame(data['content']['reviews'])

    #aux function to apply regex and remove tags
    def remove_tags(x):
        return TAG_RE.sub('',x)
    reviews['review_body'] = reviews['body'].apply(remove_tags)
    reviews['school'] = school
    return reviews

# %%
TAG_RE = re.compile(r'<[^>]+>')
def remove_tags(x):
    return TAG_RE.sub('',x)

# %%
comments = [get_comments_school(i) for i in schools_main.keys()]

comments = pd.concat(comments)

# %%
comments
# Out:
#          id                   name  anonymous hostProgramName  graduatingYear  \
# 0    305425          Minnerva Sasu      False            None          2023.0
# 1    305313        Alexander Pegot      False            None          2022.0
# 2    305209              Anonymous       True            None          2023.0
# 3    305205              Anonymous       True            None          2023.0
# 4    305099  Silvia Santillan Nava      False            None          2023.0
# ..      ...                    ...        ...             ...             ...
# 137  232119   Akshith Yellapragada      False            None          2015.0
# 138  237029          Yatri Trivedi      False            None          2016.0
# 139  232047      Jonathan Hartford      False            None          2015.0
# 140  235529          Vojtech Kotek      False            None          2017.0
# 141  234555                Jessica      False            None          2016.0
#
#     isAlumni                   jobTitle  \
# 0      False
# 1      False               Data Analyst
# 2      False
# 3      False
# 4      False                 Senior BDR
# ..       ...                        ...
# 137     True                       None
# 138     True                       None
# 139     True                       None
# 140     True  https://github.com/vkotek
# 141     True                       None
#
#                                         tagline  \
# 0                                    Amazing!!!
# 1                              Great Experience
# 2                          Incredible bootcamp!
# 3       That was amazing experience at Le wagon
# 4          Data Analytics proficient in 9 weeks
# ..                                          ...
# 137  Highly recommended! But not for beginners.
# 138    A stellar course for budding programmers
# 139                 Advanced Python Programming
# 140                             Awesome course!
# 141       Amazing course, mentors and projects!
#
#                                                   body  \
# 0    <span class="truncatable"><p></p><p>In 9 weeks...
# 1    <span class="truncatable"><p></p><p>After maki...
# 2    <span class="truncatable"><p></p><p>I feel ver...
# 3    <span class="truncatable"><p></p><p>I didn't r...
# 4    <span class="truncatable"><p></p><p>The online...
# ..                                                 ...
# 137  <span class="truncatable"><p>Getting through t...
# 138  <span class="truncatable"><p>I found this cour...
# 139  <span class="truncatable"><p>This is an excell...
# 140  <p>This course gave me a lot of knew knowledge...
# 141  <span class="truncatable"><p>I can't say enoug...
#
#                                                rawBody  ...   queryDate  \
# 0    <p>In 9 weeks, I went from procrastinating to ...  ...  2023-10-05
# 1    <p>After making the decision to pursue a caree...  ...  2023-10-02
# 2    <p>I feel very confident in my programming ski...  ...  2023-09-27
# 3    <p>I didn&#39;t really have coding knowledge i...  ...  2023-09-27
# 4    <p>The online data analytics bootcamp offered ...  ...  2023-09-22
# ..                                                 ...  ...         ...
# 137  Getting through the beginning of learning to c...  ...  2017-07-31
# 138  I found this course on reddit and applied, thi...  ...  2017-07-31
# 139  This is an excellent course.  Working with oth...  ...  2017-07-30
# 140  This course gave me a lot of knew knowledge ab...  ...  2017-03-29
# 141  I can't say enough about how helpful this cour...  ...  2016-09-01
#
#                            program             user overallScore comments  \
# 0    Data Science & AI - Full-Time  {'image': None}          5.0       []
# 1    Data Science & AI - Full-Time  {'image': None}          5.0       []
# 2      Web Development - Full-Time  {'image': None}          5.0       []
# 3      Web Development - Full-Time  {'image': None}          5.0       []
# 4       Data Analytics - Full-Time  {'image': None}          5.0       []
# ..                             ...              ...          ...      ...
# 137                   Data Science  {'image': None}          5.0       []
# 138                   Data Science  {'image': None}          5.0       []
# 139                   Data Science  {'image': None}          5.0       []
# 140                   Data Science  {'image': None}          5.0       []
# 141                           None  {'image': None}          5.0       []
#
#     overall curriculum jobSupport  \
# 0       5.0        5.0        5.0
# 1       5.0        5.0        5.0
# 2       5.0        5.0        5.0
# 3       5.0        5.0        5.0
# 4       5.0        5.0        5.0
# ..      ...        ...        ...
# 137     5.0        5.0        5.0
# 138     5.0        5.0        5.0
# 139     5.0        5.0        5.0
# 140     5.0        5.0        5.0
# 141     5.0        5.0        NaN
#
#                                            review_body    school
# 0    In 9 weeks, I went from procrastinating to doi...  le-wagon
# 1    After making the decision to pursue a career i...  le-wagon
# 2    I feel very confident in my programming skills...  le-wagon
# 3    I didn't really have coding knowledge initiall...  le-wagon
# 4    The online data analytics bootcamp offered a t...  le-wagon
# ..                                                 ...       ...
# 137  Getting through the beginning of learning to c...     rmotr
# 138  I found this course on reddit and applied, thi...     rmotr
# 139  This is an excellent course. Working with othe...     rmotr
# 140  This course gave me a lot of knew knowledge ab...     rmotr
# 141  I can't say enough about how helpful this cour...     rmotr
#
# [26355 rows x 21 columns]

# %%
comments["school"].value_counts()
# Out:
# le-wagon             2730
# springboard          1552
# udacity              1405
# shecodes             1397
# ironhack             1283
#                      ...
# fullstack-academy     153
# claim-academy         152
# rocket-academy        149
# skillcrush            145
# rmotr                 142
# Name: school, Length: 67, dtype: int64

# %%
comments.columns
# Out:
# Index(['id', 'name', 'anonymous', 'hostProgramName', 'graduatingYear',
#        'isAlumni', 'jobTitle', 'tagline', 'body', 'rawBody', 'createdAt',
#        'queryDate', 'program', 'user', 'overallScore', 'comments', 'overall',
#        'curriculum', 'jobSupport', 'review_body', 'school'],
#       dtype='object')

# %%
from pandas.io.json import json_normalize

def get_school_info(school, school_id):
    url = 'https://www.switchup.org/chimera/v1/bootcamp-data?mainTemplate=bootcamp-data%2Fdescription&path=%2Fbootcamps%2F'+ str(school) + '&isDataTarget=false&bootcampId='+ str(school_id) + '&logoTag=logo&truncationLength=250&readMoreOmission=...&readMoreText=Read%20More&readLessText=Read%20Less'

    data = requests.get(url).json()

    data.keys()

    courses = data['content']['courses']
    courses_df = pd.DataFrame(courses, columns= ['courses'])

    locations = data['content']['locations']
    locations_df = json_normalize(locations)

    badges_df = pd.DataFrame(data['content']['meritBadges'])

    website = data['content']['webaddr']
    description = data['content']['description']
    logoUrl = data['content']['logoUrl']
    school_df = pd.DataFrame([website,description,logoUrl]).T
    school_df.columns =  ['website','description','LogoUrl']

    locations_df['school'] = school
    courses_df['school'] = school
    badges_df['school'] = school
    school_df['school'] = school


    locations_df['school_id'] = school_id
    courses_df['school_id'] = school_id
    badges_df['school_id'] = school_id
    school_df['school_id'] = school_id

    return locations_df, courses_df, badges_df, school_df

locations_list = []
courses_list = []
badges_list = []
schools_list = []

for school, id in schools_main.items():
    a,b,c,d = get_school_info(school,id)

    locations_list.append(a)
    courses_list.append(b)
    badges_list.append(c)
    schools_list.append(d)
# Out:
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_14536\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_14536\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_14536\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_14536\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_14536\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_14536\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_14536\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_14536\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_14536\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_14536\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_14536\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_14536\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_14536\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_14536\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_14536\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_14536\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_14536\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_14536\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_14536\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_14536\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_14536\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_14536\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_14536\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_14536\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_14536\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_14536\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_14536\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_14536\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_14536\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_14536\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_14536\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_14536\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_14536\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_14536\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_14536\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_14536\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_14536\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_14536\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_14536\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_14536\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_14536\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_14536\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_14536\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_14536\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_14536\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_14536\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_14536\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_14536\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_14536\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_14536\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_14536\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_14536\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_14536\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_14536\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_14536\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_14536\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_14536\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_14536\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_14536\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_14536\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_14536\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_14536\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_14536\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_14536\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_14536\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_14536\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_14536\3406472284.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)

# %%
locations = pd.concat(locations_list)
locations
# Out:
#        id              description  country.id country.name country.abbrev  \
# 0   15803     Melbourne, Australia        20.0    Australia             AU
# 1   15904      Casablanca, Morocco        44.0      Morocco             MA
# 2   15906  Buenos Aires, Argentina        60.0    Argentina             AR
# 3   15964        Brussels, Belgium        46.0      Belgium             BE
# 4   16039      Mexico City, Mexico        29.0       Mexico             MX
# ..    ...                      ...         ...          ...            ...
# 1   17703                Singapore        56.0    Singapore             SG
# 2   18140   Kowloon Bay, Hong Kong       144.0    Hong Kong             HK
# 3   18141        Sydney, Australia        20.0    Australia             AU
# 0   15796                   Online         NaN          NaN            NaN
# 0   16270                   Online         NaN          NaN            NaN
#
#     city.id     city.name  city.keyword  state.id state.name state.abbrev  \
# 0   31174.0     Melbourne     melbourne       NaN        NaN          NaN
# 1   31119.0    Casablanca    casablanca       NaN        NaN          NaN
# 2   31171.0  Buenos Aires  buenos-aires       NaN        NaN          NaN
# 3   31125.0      Brussels      brussels       NaN        NaN          NaN
# 4   31175.0   Mexico City   mexico-city       NaN        NaN          NaN
# ..      ...           ...           ...       ...        ...          ...
# 1   31154.0     Singapore     singapore       NaN        NaN          NaN
# 2   31280.0   Kowloon Bay   kowloon-bay       NaN        NaN          NaN
# 3   31110.0        Sydney        sydney       NaN        NaN          NaN
# 0       NaN           NaN           NaN       1.0     Online       Online
# 0       NaN           NaN           NaN       1.0     Online       Online
#
#    state.keyword          school school_id
# 0            NaN        le-wagon     10868
# 1            NaN        le-wagon     10868
# 2            NaN        le-wagon     10868
# 3            NaN        le-wagon     10868
# 4            NaN        le-wagon     10868
# ..           ...             ...       ...
# 1            NaN  rocket-academy     11483
# 2            NaN  rocket-academy     11483
# 3            NaN  rocket-academy     11483
# 0         online      skillcrush     11020
# 0         online           rmotr     10987
#
# [424 rows x 14 columns]

# %%
courses = pd.concat(courses_list)
courses
# Out:
#                                               courses      school school_id
# 0                          Data Analytics - Full-Time    le-wagon     10868
# 1                          Data Analytics - Part-Time    le-wagon     10868
# 2                        Data Engineering - Full-Time    le-wagon     10868
# 3                        Data Engineering - Part-Time    le-wagon     10868
# 4                       Data Science & AI - Full-Time    le-wagon     10868
# ..                                                ...         ...       ...
# 0     Break Into Tech + Job Guarantee: Designer Track  skillcrush     11020
# 1   Break Into Tech + Job Guarantee: Front End Dev...  skillcrush     11020
# 2                              Skillcrush Coding Camp  skillcrush     11020
# 0                            Data Science with Python       rmotr     10987
# 1                         Web Development with Django       rmotr     10987
#
# [554 rows x 3 columns]

# %%
badges = pd.concat(badges_list)
badges["description"] = badges["description"].apply(remove_tags)
badges["description"]
# Out:
# 0             School offers fully online courses
# 1    School offers part-time and evening classes
# 0             School offers fully online courses
# 1    School offers part-time and evening classes
# 2                School guarantees job placement
#                         ...
# 0             School offers fully online courses
# 1    School offers part-time and evening classes
# 2                School guarantees job placement
# 0             School offers fully online courses
# 1    School offers part-time and evening classes
# Name: description, Length: 161, dtype: object

# %%
schools = pd.concat(schools_list)

def schools_cleaning(row):
    from bs4 import BeautifulSoup
    soup = BeautifulSoup(row)
    text = [tag.get_text() for tag in soup.find_all(['p', 'span'])]
    return ' '.join(text)

schools["description"] = schools["description"].apply(schools_cleaning)

# %%
schools = pd.merge(schools_main, schools, how='outer', on="school_id").set_index("school").reset_index()
schools
# Out:
#                school school_id  \
# 0            le-wagon     10868
# 1         springboard     11035
# 2             udacity     11118
# 3            shecodes     11014
# 4            ironhack     10828
# ..                ...       ...
# 62  fullstack-academy     10751
# 63      claim-academy     10589
# 64     rocket-academy     11483
# 65         skillcrush     11020
# 66              rmotr     10987
#
#                                               website  \
# 0                                     www.lewagon.com
# 1   www.springboard.com/?utm_source=switchup&utm_m...
# 2   www.udacity.com/?utm_source=switchup&utm_mediu...
# 3                                         shecodes.io
# 4                                 www.ironhack.com/en
# ..                                                ...
# 62                           www.fullstackacademy.com
# 63                                claimacademystl.com
# 64                                  rocketacademy.co/
# 65                                     skillcrush.com
# 66                                          rmotr.com
#
#                                           description  \
# 0   Le Wagon is a global leader in immersive tech ...
# 1   Springboard is an online learning platform tha...
# 2   Udacity is the trusted market leader in talent...
# 3   SheCodes is a coding school that offers online...
# 4   Ironhack is a global tech school with 9 campus...
# ..                                                ...
# 62  Founded in 2012, Fullstack Academy is one of t...
# 63  Claim Academy is a premier developer boot camp...
# 64  Rocket Academy is a 6-month live and online co...
# 65  Skillcrush has more than 17,000 students in al...
# 66  RMOTR school is one of the leading online Pyth...
#
#                                               LogoUrl
# 0   https://d92mrp7hetgfk.cloudfront.net/images/si...
# 1   https://d92mrp7hetgfk.cloudfront.net/images/si...
# 2   https://d92mrp7hetgfk.cloudfront.net/images/si...
# 3   https://d92mrp7hetgfk.cloudfront.net/images/si...
# 4   https://d92mrp7hetgfk.cloudfront.net/images/si...
# ..                                                ...
# 62  https://d92mrp7hetgfk.cloudfront.net/images/si...
# 63  https://d92mrp7hetgfk.cloudfront.net/images/si...
# 64  https://d92mrp7hetgfk.cloudfront.net/images/si...
# 65  https://d92mrp7hetgfk.cloudfront.net/images/si...
# 66  https://d92mrp7hetgfk.cloudfront.net/images/si...
#
# [67 rows x 5 columns]
